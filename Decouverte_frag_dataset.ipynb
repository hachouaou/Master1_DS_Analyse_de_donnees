# %%
import pandas as pd

df = pd.read_csv('frag_dataset.csv')

# %%
df.sample(7)
# Out:
#                    brand                perfume        image  launch_year  \
# 34400    SWITCH Perfumes                      3  o.33127.jpg       2015.0
# 5325   Hov Parfumeur Ltd                Jasmine  o.39722.jpg          NaN
# 22218      Dolce Gabbana  Light Blue pour Homme   o.1068.jpg       2007.0
# 23470             Krizia      Teatro Alla Scala   o.5590.jpg       1985.0
# 13825           G Nejman             Le Sportif  o.18844.jpg       2009.0
# 21832             Byblos          Blu Men Enjoy   o.1557.jpg       2005.0
# 28152      The Body Shop             White Musk   o.2432.jpg          NaN
#
#                                             main_accords  \
# 34400  ["woody", "aromatic", "balsamic", "white flora...
# 5325              ["white floral", "animalic", "floral"]
# 22218  ["citrus", "fresh spicy", "woody", "aromatic",...
# 23470  ["warm spicy", "balsamic", "animalic", "woody"...
# 13825  ["citrus", "aromatic", "marine", "fresh", "ozo...
# ...
